# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\realtor-data.zip.csv")

# %%
df.shape
# Out:
# (2226382, 12)

# %%
df.isnull().sum()
# Out:
# brokered_by         4533
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# street             10866
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.dropna()

# %%
df = df.reset_index(drop = True)

# %%
df.shape
# Out:
# (1084909, 12)

# %%
df.head()
# Out:
#    brokered_by    status      price  bed  bath  acre_lot     street  \
# 0      92147.0  for_sale   110000.0  7.0   3.0      0.09  1842706.0
# 1      94933.0  for_sale   950000.0  5.0   4.0      0.99  1260473.0
# 2     103341.0  for_sale  6899000.0  4.0   6.0      0.83    17467.0
# 3      21163.0  for_sale   525000.0  3.0   3.0      0.45  1813270.0
# 4      67455.0  for_sale   289900.0  3.0   2.0      0.36  1698080.0
#
#            city           state  zip_code  house_size prev_sold_date
# 0        Dorado     Puerto Rico     949.0      1192.0     2019-06-28
# 1  Saint Thomas  Virgin Islands     802.0      5000.0     2013-10-11
# 2  Saint Thomas  Virgin Islands     802.0      4600.0     2018-04-05
# 3        Agawam   Massachusetts    1001.0      2314.0     2014-06-25
# 4        Agawam   Massachusetts    1001.0      1276.0     2012-10-12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084909 entries, 0 to 1084908
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   brokered_by     1084909 non-null  float64
#  1   status          1084909 non-null  object
#  2   price           1084909 non-null  float64
#  3   bed             1084909 non-null  float64
#  4   bath            1084909 non-null  float64
#  5   acre_lot        1084909 non-null  float64
#  6   street          1084909 non-null  float64
#  7   city            1084909 non-null  object
#  8   state           1084909 non-null  object
#  9   zip_code        1084909 non-null  float64
#  10  house_size      1084909 non-null  float64
#  11  prev_sold_date  1084909 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 99.3+ MB

# %%
df.state.value_counts().head(6)
# Out:
# state
# California      157724
# Florida         107570
# Texas           106040
# Arizona          50269
# Pennsylvania     42670
# Georgia          42384
# Name: count, dtype: int64

# %% [markdown]
# ### EDA on California, Florida, Pennsyvalnia, Arizona and Texas

# %%
data = df[(df.state == 'California')|(df.state == 'Texas') | (df.state == 'Florida') | (df.state == 'Arizona') | (df.state == 'Pennsylvania')].reset_index(drop = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464273 entries, 0 to 464272
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   brokered_by     464273 non-null  float64
#  1   status          464273 non-null  object
#  2   price           464273 non-null  float64
#  3   bed             464273 non-null  float64
#  4   bath            464273 non-null  float64
#  5   acre_lot        464273 non-null  float64
#  6   street          464273 non-null  float64
#  7   city            464273 non-null  object
#  8   state           464273 non-null  object
#  9   zip_code        464273 non-null  float64
#  10  house_size      464273 non-null  float64
#  11  prev_sold_date  464273 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 42.5+ MB

# %% [markdown]
# ### Checking the number of unique values in each features

# %%
data.nunique()
# Out:
# brokered_by        37983
# status                 2
# price              21471
# bed                   58
# bath                  56
# acre_lot            3492
# street            427351
# city                4321
# state                  5
# zip_code            5668
# house_size          8337
# prev_sold_date     12150
# dtype: int64

# %%
data.bath.unique()
# Out:
# array([  3.,   1.,   2.,   4.,   5.,   7.,   6.,   8.,  10.,  11.,   9.,
#         14.,  17.,  12.,  18.,  15.,  13.,  21.,  16.,  22.,  19.,  69.,
#         24.,  70.,  25.,  20.,  27.,  54.,  36.,  30.,  44.,  49.,  78.,
#         35.,  47.,  32.,  28.,  40.,  26.,  66.,  37.,  33.,  42.,  48.,
#         39.,  38., 108.,  34.,  64.,  23.,  29., 175.,  53.,  99.,  45.,
#         50.])

# %% [raw]
# Comment: There are outliers in the bathroom and bedroom features because there can never be a house with 175 bedrooms

# %%
data = data[data.city != 'California']

# %%
data = data.sort_values('prev_sold_date')

# %%
data.describe()
# Out:
#          brokered_by         price            bed           bath  \
# count  464265.000000  4.642650e+05  464265.000000  464265.000000
# mean    53140.745458  7.038986e+05       3.309041       2.522314
# std     30642.184532  1.605311e+06       1.231918       1.273989
# min         4.000000  1.000000e+00       1.000000       1.000000
# 25%     23592.000000  2.920000e+05       3.000000       2.000000
# 50%     52985.000000  4.409900e+05       3.000000       2.000000
# 75%     79290.000000  7.250000e+05       4.000000       3.000000
# max    110142.000000  5.150000e+08     108.000000     175.000000
#
#             acre_lot        street       zip_code    house_size
# count  464265.000000  4.642650e+05  464265.000000  4.642650e+05
# mean       10.294220  9.281851e+05   67895.855744  1.999001e+03
# std       792.080869  5.255810e+05   27828.584309  2.563989e+03
# min         0.000000  2.905000e+03   11745.000000  1.000000e+02
# 25%         0.130000  4.713890e+05   33928.000000  1.335000e+03
# 50%         0.180000  9.192330e+05   77541.000000  1.750000e+03
# 75%         0.290000  1.386473e+06   92037.000000  2.343000e+03
# max    100000.000000  2.001125e+06   96161.000000  1.560780e+06

# %% [markdown]
# ### Handling the Outliers

# %%
num_df = data.select_dtypes([int,float])
for col in num_df.columns:
    if col == 'brokered_by' or col == 'street' or col == 'zip_code':
        continue
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    upper = Q3 + (1.5*IQR)
    lower = Q1 - (1.5*IQR)
    mask = (data[col] > upper) | (data[col] < lower)
    data = data[~(mask)]

# %%
data.shape
# Out:
# (290712, 12)

# %% [raw]
# exporting the cleaned and filtered data to csv file

# %%
data.to_csv('cleaned_realtor_zip.csv')

# %% [raw]
# working with the cleaned data.

# %%
data = pd.read_csv('cleaned_realtor_zip.csv')

# %%
data.nunique()
# Out:
# Unnamed: 0        290712
# brokered_by        29774
# status                 2
# price              14287
# bed                    4
# bath                   4
# acre_lot              34
# street            267387
# city                3220
# state                  5
# zip_code            4673
# house_size          2644
# prev_sold_date     10684
# dtype: int64

# %% [markdown]
# ### Checking if a House was resold or not

# %%
resold = data.groupby(['bed','street','bath','acre_lot','city','state','zip_code','house_size']).size().reset_index(name = 'count').sort_values('count', ascending = False)

# %%
resold.head()
# Out:
#         bed     street  bath  acre_lot          city         state  zip_code  \
# 95438   3.0   632472.0   2.0      0.02  Philadelphia  Pennsylvania   19130.0
# 233815  4.0  1174592.0   2.0      0.06   Upper Darby  Pennsylvania   19082.0
# 51151   3.0    44584.0   1.0      0.06         Darby  Pennsylvania   19023.0
# 97492   3.0   662730.0   2.0      0.24         Ocala       Florida   34472.0
# 136357  3.0  1164059.0   2.0      0.03   Upper Darby  Pennsylvania   19082.0
#
#         house_size  count
# 95438       1734.0      3
# 233815      1612.0      3
# 51151       1232.0      3
# 97492       1559.0      3
# 136357      1644.0      3

# %%
sns.histplot(x = 'count', data =  resold, hue = 'state')
plt.xlabel('Number of Times Houses were resold')
plt.ylabel('Number of Houses')
plt.title('The Number of Houses Resold')
plt.show()

# %%
resold[resold['count'] == 3]
# Out:
#         bed     street  bath  acre_lot          city         state  zip_code  \
# 95438   3.0   632472.0   2.0      0.02  Philadelphia  Pennsylvania   19130.0
# 233815  4.0  1174592.0   2.0      0.06   Upper Darby  Pennsylvania   19082.0
# 51151   3.0    44584.0   1.0      0.06         Darby  Pennsylvania   19023.0
# 97492   3.0   662730.0   2.0      0.24         Ocala       Florida   34472.0
# 136357  3.0  1164059.0   2.0      0.03   Upper Darby  Pennsylvania   19082.0
# 75462   3.0   365163.0   1.0      0.04   Marcus Hook  Pennsylvania   19061.0
# 130907  3.0  1090422.0   3.0      0.01  Philadelphia  Pennsylvania   19148.0
# 137649  3.0  1180872.0   2.0      0.11       Phoenix       Arizona   85028.0
#
#         house_size  count
# 95438       1734.0      3
# 233815      1612.0      3
# 51151       1232.0      3
# 97492       1559.0      3
# 136357      1644.0      3
# 75462       1210.0      3
# 130907      1842.0      3
# 137649      1764.0      3

# %% [raw]
# insight: some houses were resold three times and most were just listed for sale or sold once.

# %% [markdown]
# ### Generating Statistical Summary

# %%
data.describe()
# Out:
#           Unnamed: 0    brokered_by          price            bed  \
# count  290712.000000  290712.000000  290712.000000  290712.000000
# mean   231009.350347   53985.027863  410714.147269       3.138783
# std    131960.049136   30361.281211  194372.808701       0.744591
# min         2.000000       4.000000       1.000000       2.000000
# 25%    114085.750000   26022.000000  266000.000000       3.000000
# 50%    237506.500000   53016.000000  375000.000000       3.000000
# 75%    337569.250000   79307.000000  529000.000000       4.000000
# max    464272.000000  110142.000000  923000.000000       5.000000
#
#                 bath       acre_lot        street       zip_code  \
# count  290712.000000  290712.000000  2.907120e+05  290712.000000
# mean        2.227025       0.156105  9.339698e+05   66248.376170
# std         0.683710       0.070428  5.259293e+05   27652.237613
# min         1.000000       0.000000  6.085000e+03   15001.000000
# 25%         2.000000       0.110000  4.747460e+05   33844.000000
# 50%         2.000000       0.160000  9.307935e+05   77379.000000
# 75%         3.000000       0.200000  1.391824e+06   91301.000000
# max         4.000000       0.330000  2.001125e+06   96161.000000
#
#           house_size
# count  290712.000000
# mean     1684.629482
# std       531.491008
# min       198.000000
# 25%      1281.000000
# 50%      1614.000000
# 75%      2021.000000
# max      3131.000000

# %% [raw]
# There are still some outliers in the dataset where by we are having the minimum value of the land area to be zero

# %%
data = data[data.acre_lot != 0.00]

# %% [markdown]
# ### Checking the Distribution of Each Feature

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'status', hue = 'state', data = data, linewidth = 0.5)
plt.title('Status Distribution')
plt.show()

# %% [markdown]
# #### Insights
# 1. California has the highest record of sold houses.
# 2. Florida has the highest record of houses for sale and it almost have equal distribution of sold and for sale houses.
# 3. Houses for sale and sold in pennsylvania are not quite much.
# 4. Houses for sale in texas are also quite much.

# %%
sns.set_style('darkgrid')
sns.histplot(x = 'price', hue = 'state', bins =  40, data = data, kde = True )
plt.ylabel('frequency')
plt.title('Price Distribution')
plt.show()

# %% [markdown]
# ### Insights
# - Generally in the five states, most houses are priced within the range of 300k dollars.
# - In california, houses around 600k and 800k are quite much.
# - In florida, most houses are priced within the range of 250 to 400k.
# - In pennsylvania, most houses are within the of 200k to 250k.
# - In Arizona, most houses are priced around 400k dollars.
# - In Texas, most houses are priced around 250k dollars and 300k dollars.

# %%
sns.set_style('darkgrid')
sns.histplot(y = 'bed', data = data, hue ='state')
plt.title('Bedroom Distribution')
plt.show()

# %% [markdown]
# #### Insights
# - Most houses has 3 bedrooms

# %%
sns.set_style('darkgrid')
sns.histplot(y = 'bath', data = data, hue ='state')
plt.title('Bathroom Distribution')
plt.show()

# %% [markdown]
# ### Insights
# - Most houses has 2 bathrooms.
# -

# %% [markdown]
# #### Checking City Distribution

# %%
data.city.value_counts().head(20).index
# Out:
# Index(['Houston', 'Tucson', 'Phoenix', 'Philadelphia', 'Fort Worth',
#        'Sacramento', 'Orlando', 'Dallas', 'Tampa', 'El Paso', 'San Antonio',
#        'Mesa', 'Kissimmee', 'Pittsburgh', 'Katy', 'Cape Coral', 'Stockton',
#        'Saint Petersburg', 'Ocala', 'Miami'],
#       dtype='object', name='city')

# %% [markdown]
# > These are the top 20 most popular cities

# %%
sns.set_style('darkgrid')
sns.countplot(y = 'state', data =data, color = 'purple',edgecolor = 'black', linewidth = 0.2)
plt.title('State Distribution')
plt.show()

# %% [raw]
# This would be useful when deploying an interface for our models. Decision on the number of cities would depend on the percentage of each states in the state distribution.

# %%
sns.set_style('darkgrid')
sns.histplot(x = 'house_size', data = data, hue = 'state', bins =40, kde = True)
plt.title('House_size distribution')
plt.show()

# %% [markdown]
# ### Insights
# 1. Most house sizes in California are within the range of 1200 square feet to 1500 square feet.
# 2. Most house sizes in Texas are within the range of 1500 sqt to 2000 sqt.
# 3. In Pennsylvania, most house sizes are in the range of 1000 and 1500 sqt.
# 4. In Arizona, most house sizes are within the range of 1500 and 1700 sqt.
# 5. In Florida, most house sizes are

# %%
sns.set_style('darkgrid')
sns.histplot(x = 'acre_lot', data = data, hue = 'state', bins =30, kde = True)
plt.title('Lot SIze distribution')
plt.show()

# %% [markdown]
# ### Insights
# 1. Land sizes in california are mostly within the range of 0.15 and 0.17 acres.
# 2. Land sizes in florida are mostly around 0.23 acres.
# 3. Land sizes in arizona are mostly around 0.15 acres.
# 4. Land sizes in Texas are mostly around 0.16 acres.
# 5. Land sizes in pennsylvania are mostly around 0.01 acres.

# %%
data.describe()
# Out:
#           Unnamed: 0    brokered_by          price            bed  \
# count  290119.000000  290119.000000  290119.000000  290119.000000
# mean   231015.297226   53973.361114  410749.462827       3.140194
# std    131963.593693   30363.419830  194443.313924       0.744079
# min         2.000000       4.000000       1.000000       2.000000
# 25%    114032.000000   26008.000000  265998.000000       3.000000
# 50%    237511.000000   53016.000000  375000.000000       3.000000
# 75%    337453.500000   79303.000000  529000.000000       4.000000
# max    464272.000000  110142.000000  923000.000000       5.000000
#
#                 bath       acre_lot        street       zip_code  \
# count  290119.000000  290119.000000  2.901190e+05  290119.000000
# mean        2.227238       0.156424  9.340020e+05   66242.953836
# std         0.683934       0.070145  5.258243e+05   27651.040868
# min         1.000000       0.010000  6.085000e+03   15001.000000
# 25%         2.000000       0.110000  4.749705e+05   33844.000000
# 50%         2.000000       0.160000  9.308570e+05   77377.000000
# 75%         3.000000       0.200000  1.391680e+06   91304.000000
# max         4.000000       0.330000  2.001125e+06   96161.000000
#
#           house_size
# count  290119.000000
# mean     1685.178651
# std       531.574320
# min       198.000000
# 25%      1282.000000
# 50%      1614.000000
# 75%      2022.000000
# max      3131.000000

# %% [raw]
# The statistical summary revealed some outliers so we would still clean the data.

# %%
data = data[data.house_size >300]

# %%
data = data[data.price > 10000 ]

# %%
data = data[data.acre_lot > 0.01]

# %%
data.shape
# Out:
# (287870, 13)

# %% [markdown]
# ### Feature Engineering

# %%
data['year_sold'] = data['prev_sold_date'].str.split('-').str.get(0)

month_dict = {'01': 'January','02':'February','03':'March','04':'April', '05':'May','06':'June','07':'July',
             '08':'August', '09': 'September', '10': 'October', '11': 'November', '12':'December'}

data['month_sold'] = data['prev_sold_date'].str.split('-').str.get(1).map(month_dict)

data['prev_sold_date'] = pd.to_datetime(data.prev_sold_date).dt.date

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# brokered_by       0
# status            0
# price             0
# bed               0
# bath              0
# acre_lot          0
# street            0
# city              0
# state             0
# zip_code          0
# house_size        0
# prev_sold_date    0
# year_sold         0
# month_sold        0
# dtype: int64

# %%
data.head(5)
# Out:
#    Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 0        3307      31684.0  for_sale  250000.0  3.0   2.0      0.02
# 1        9985      88745.0  for_sale  159900.0  3.0   2.0      0.08
# 2      169855      56941.0  for_sale  595000.0  4.0   2.0      0.14
# 3        7412      45827.0  for_sale  195000.0  4.0   3.0      0.14
# 4      169677     104223.0  for_sale  649000.0  4.0   2.0      0.18
#
#       street          city         state  zip_code  house_size prev_sold_date  \
# 0   295324.0  Philadelphia  Pennsylvania   19143.0      1086.0     1956-10-25
# 1   312812.0       Palmyra  Pennsylvania   17078.0      1424.0     1959-01-16
# 2  1227344.0       Salinas    California   93906.0      1192.0     1961-09-26
# 3  1015944.0    Pittsburgh  Pennsylvania   15210.0      2030.0     1962-03-30
# 4   380186.0       Salinas    California   93906.0      1240.0     1962-07-03
#
#   year_sold month_sold
# 0      1956    October
# 1      1959    January
# 2      1961  September
# 3      1962      March
# 4      1962       July

# %% [markdown]
# ### Exhaustive Analysis

# %%
data.brokered_by.nunique()
# Out:
# 29659

# %% [raw]
# checking whether real estate agents have effect on the price of houses

# %%
data.groupby('brokered_by')['price'].mean().reset_index(name = 'avg').sort_values('avg', ascending = False).head(5)
# Out:
#        brokered_by       avg
# 26736      99138.0  921300.0
# 13087      49092.0  920000.0
# 26790      99307.0  920000.0
# 17492      66436.0  920000.0
# 8828       33338.0  920000.0

# %%
data.head(2)
# Out:
#    Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot    street  \
# 0        3307      31684.0  for_sale  250000.0  3.0   2.0      0.02  295324.0
# 1        9985      88745.0  for_sale  159900.0  3.0   2.0      0.08  312812.0
#
#            city         state  zip_code  house_size prev_sold_date year_sold  \
# 0  Philadelphia  Pennsylvania   19143.0      1086.0     1956-10-25      1956
# 1       Palmyra  Pennsylvania   17078.0      1424.0     1959-01-16      1959
#
#   month_sold
# 0    October
# 1    January

# %% [markdown]
# ### Analysis on House Status

# %%
data.groupby('status')['price'].mean().reset_index()
# Out:
#      status          price
# 0  for_sale  413781.979474
# 1      sold  409952.283585

# %%
forsale = data[data.status == 'for_sale']

# %%
sold = data[data.status == 'sold']

# %%
forsale.shape
# Out:
# (111320, 15)

# %%
forsale.head(2)
# Out:
#    Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot    street  \
# 0        3307      31684.0  for_sale  250000.0  3.0   2.0      0.02  295324.0
# 1        9985      88745.0  for_sale  159900.0  3.0   2.0      0.08  312812.0
#
#            city         state  zip_code  house_size prev_sold_date year_sold  \
# 0  Philadelphia  Pennsylvania   19143.0      1086.0     1956-10-25      1956
# 1       Palmyra  Pennsylvania   17078.0      1424.0     1959-01-16      1959
#
#   month_sold
# 0    October
# 1    January

# %%
cols = ['status','bed','bath','acre_lot','street','city','state','zip_code','house_size']

# %% [raw]
# checking the number of times a property was listed for sale.

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
forsale['no_of_times_listed'] = forsale.groupby(cols)['acre_lot'].transform('count')

# %%
forsale.no_of_times_listed.value_counts()
# Out:
# no_of_times_listed
# 1    110869
# 2       448
# 3         3
# Name: count, dtype: int64

# %%
sns.histplot(x = forsale.no_of_times_listed, hue = 'state', data = forsale)
plt.show()

# %%
forsale[forsale.no_of_times_listed > 2].sort_values('brokered_by', ascending = True)
# Out:
#       Unnamed: 0  brokered_by    status    price  bed  bath  acre_lot  \
# 3196        3216      83377.0  for_sale  89000.0  3.0   1.0      0.06
# 3198       18693      83377.0  for_sale  83000.0  3.0   1.0      0.06
# 3199       19423      83377.0  for_sale  78000.0  3.0   1.0      0.06
#
#        street   city         state  zip_code  house_size prev_sold_date  \
# 3196  44584.0  Darby  Pennsylvania   19023.0      1232.0     1988-08-11
# 3198  44584.0  Darby  Pennsylvania   19023.0      1232.0     1988-08-11
# 3199  44584.0  Darby  Pennsylvania   19023.0      1232.0     1988-08-11
#
#      year_sold month_sold  no_of_times_listed
# 3196      1988     August                   3
# 3198      1988     August                   3
# 3199      1988     August                   3

# %% [raw]
# Insight: The price of an house in darby appreciated and also depreciated the same day it was list for sale.

# %% [raw]
# Analysing Houses listed twice

# %%
listed_twice = forsale[forsale.no_of_times_listed == 2].sort_values('brokered_by', ascending = True)

# %%
sns.countplot(listed_twice.state)
plt.show()

# %% [raw]
# insights: Pennsylvania has the highest proportion of houses listed twice.

# %%
from functools import reduce

# %%
bool_list = []

# %%
def func(arg):
    reduce(lambda x, y: bool_list.append(True) if x > y else bool_list.append(False), arg)

# %%
listed_twice.groupby(cols)['price'].transform(func)
# Out:
# 87708    NaN
# 87689    NaN
# 54823    NaN
# 54831    NaN
# 77590    NaN
#           ..
# 225408   NaN
# 65378    NaN
# 403      NaN
# 66278    NaN
# 66294    NaN
# Name: price, Length: 448, dtype: float64

# %%
pd.Series(bool_list).value_counts()
# Out:
# False    120
# True     104
# Name: count, dtype: int64

# %% [raw]
# The idea behind this algorithm is that:
# - False means their price increased.
# - True means their price reduced.

# %% [raw]
# some homes appreciated while some depreciated since most appreciated, we can conclude that some house value increased while listed for sales

# %% [markdown]
# #### Analyzing Sold Houses

# %%
sold['no_of_times_sold'] = sold.groupby(cols)['brokered_by'].transform('count')

# %%
sold.no_of_times_sold.value_counts()
# Out:
# no_of_times_sold
# 1    176536
# 2        14
# Name: count, dtype: int64

# %% [raw]
# insights: just seven houses were sold twice and they are located in Florida and Arizona.

# %%
sold[sold.no_of_times_sold == 2].sort_values('zip_code', ascending =True)
# Out:
#         Unnamed: 0  brokered_by status     price  bed  bath  acre_lot  \
# 222637      190246      23087.0   sold  549900.0  2.0   2.0      0.02
# 222923      209389      16829.0   sold  549900.0  2.0   2.0      0.02
# 250488      208333      23087.0   sold  629000.0  3.0   2.0      0.02
# 251039      209532      16829.0   sold  629000.0  3.0   2.0      0.02
# 204731      209520      16829.0   sold  159900.0  3.0   1.0      0.02
# 204753      189921      23087.0   sold  159900.0  3.0   1.0      0.02
# 269055      258359      38891.0   sold  259900.0  3.0   2.0      0.24
# 278929      212372      38891.0   sold  259900.0  3.0   2.0      0.24
# 124164      272533      97820.0   sold  165000.0  3.0   2.0      0.14
# 205055      274251     102604.0   sold  239990.0  3.0   2.0      0.14
# 285608      344253      41784.0   sold  600000.0  3.0   2.0      0.11
# 288745      331431      41784.0   sold  600000.0  3.0   2.0      0.11
# 281769      339339      22611.0   sold   52000.0  3.0   2.0      0.11
# 289591      343950      22611.0   sold   52000.0  3.0   2.0      0.11
#
#            street          city         state  zip_code  house_size  \
# 222637  1744303.0  Philadelphia  Pennsylvania   19130.0      1470.0
# 222923  1744303.0  Philadelphia  Pennsylvania   19130.0      1470.0
# 250488   632472.0  Philadelphia  Pennsylvania   19130.0      1734.0
# 251039   632472.0  Philadelphia  Pennsylvania   19130.0      1734.0
# 204731   448300.0  Philadelphia  Pennsylvania   19145.0      1030.0
# 204753   448300.0  Philadelphia  Pennsylvania   19145.0      1030.0
# 269055   662730.0         Ocala       Florida   34472.0      1559.0
# 278929   662730.0         Ocala       Florida   34472.0      1559.0
# 124164    61390.0        Dallas         Texas   75217.0      1319.0
# 205055    61390.0        Dallas         Texas   75217.0      1319.0
# 285608  1180872.0       Phoenix       Arizona   85028.0      1764.0
# 288745  1180872.0       Phoenix       Arizona   85028.0      1764.0
# 281769  1654653.0          Mesa       Arizona   85207.0       960.0
# 289591  1654653.0          Mesa       Arizona   85207.0       960.0
#
#        prev_sold_date year_sold month_sold  no_of_times_sold
# 222637     2022-03-16      2022      March                 2
# 222923     2022-03-16      2022      March                 2
# 250488     2022-04-06      2022      April                 2
# 251039     2022-04-06      2022      April                 2
# 204731     2022-03-01      2022      March                 2
# 204753     2022-03-01      2022      March                 2
# 269055     2022-04-19      2022      April                 2
# 278929     2022-04-25      2022      April                 2
# 124164     2021-11-30      2021   November                 2
# 205055     2022-03-01      2022      March                 2
# 285608     2022-04-29      2022      April                 2
# 288745     2022-05-02      2022        May                 2
# 281769     2022-04-27      2022      April                 2
# 289591     2022-05-03      2022        May                 2

# %% [raw]
# These Houses were resold for the same price but not on the same day.
# - Also a house in dallas texas appreciated in value within a year, it was sold for 165k dollars in november 2021 then in March 2022 it was sold for 240k dollars.

# %% [raw]
# checking the properties sold and listed for sale

# %%
data['forsale/sold'] = data.groupby(['bed','bath','acre_lot','street','city','state','zip_code','house_size'])['status'].transform(lambda x: ",".join(x.unique()))

# %%
data['forsale/sold'].value_counts()
# Out:
# forsale/sold
# sold             154100
# for_sale          88870
# for_sale,sold     44376
# sold,for_sale       524
# Name: count, dtype: int64

# %% [raw]
# The total number of properties listed for sale and sold is 22,450

# %%
data[['bed','bath','acre_lot','street','city','state','zip_code','house_size']].duplicated().sum()
# Out:
# 22680

# %% [raw]
# creating a new dataframe for sold and listed

# %%
re_sold = data[(data['forsale/sold'] =='for_sale,sold')|(data['forsale/sold'] == 'sold,for_sale')].sort_values('house_size').drop_duplicates()

# %%
re_sold.state.value_counts()
# Out:
# state
# California      12878
# Florida         10941
# Texas            9908
# Arizona          8465
# Pennsylvania     2708
# Name: count, dtype: int64

# %% [markdown]
# ### Conducting Analysis Based On States

# %% [raw]
# checking average prices houses across each states

# %%
avg_price = data.groupby('state')['price'].mean().reset_index()

# %%
sns.set_style('darkgrid')
sns.barplot(x = 'state', y = 'price', data = avg_price, color ='cyan')
plt.title('Average Prices of Houses across States')
plt.ylabel('Average House Price')
plt.show()

# %% [raw]
# insights: Average House Price in California is more than any other states.
# - This shows that California has more expensive housing.
# - While pennsylvania has more affordable housing.

# %% [raw]
# Let's check their standard deviation

# %%
data.groupby('state')['price'].std()
# Out:
# state
# Arizona         151523.183759
# California      182797.016736
# Florida         161645.322468
# Pennsylvania    135342.825036
# Texas           135992.645107
# Name: price, dtype: float64

# %% [raw]
# - California has the highest standard deviation and this shows there are also affordable houses in california.
# - Pennyslvania has the lowest standard deviation.

# %%
city_dict = {}
for x in data.state.unique():
    length = data[data.state ==x]['city'].nunique()
    city_dict.update({x:length})

# %%
pd.DataFrame(city_dict, index = ['Number of cities'])
# Out:
#                   Pennsylvania  California  Florida  Arizona  Texas
# Number of cities           985         914      526      158    828

# %% [raw]
# This would be needed during user selection

# %% [markdown]
# ### Analysis on Houses in California

# %%
california = data[data.state == 'California']

# %%
california.head(2)
# Out:
#    Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 2      169855      56941.0  for_sale  595000.0  4.0   2.0      0.14
# 4      169677     104223.0  for_sale  649000.0  4.0   2.0      0.18
#
#       street     city       state  zip_code  house_size prev_sold_date  \
# 2  1227344.0  Salinas  California   93906.0      1192.0     1961-09-26
# 4   380186.0  Salinas  California   93906.0      1240.0     1962-07-03
#
#   year_sold month_sold forsale/sold
# 2      1961  September     for_sale
# 4      1962       July     for_sale

# %%
california.shape
# Out:
# (78886, 16)

# %%
sns.boxplot(california.price)
# Out:
# <Axes: ylabel='price'>

# %% [raw]
# conducting analysis on twenty cities

# %%
city_dict = california.city.value_counts().head(20).to_dict()

# %%
california['city_freq'] = california.city.map(city_dict)

# %%
sample_california = california.dropna()

# %%
sample_california.sample(5)
# Out:
#         Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 966         140637      78364.0  for_sale  579000.0  2.0   1.0      0.06
# 248881      417534     109042.0      sold  409000.0  4.0   3.0      0.15
# 159937      447817      98963.0      sold  538500.0  3.0   3.0      0.33
# 82873       152645      35346.0  for_sale  389000.0  2.0   2.0      0.03
# 287835      407270      65047.0      sold  540000.0  4.0   2.0      0.17
#
#            street           city       state  zip_code  house_size  \
# 966      382795.0     Long Beach  California   90804.0       668.0
# 248881  1763501.0    Bakersfield  California   93311.0      2122.0
# 159937   139693.0        Modesto  California   95351.0      2345.0
# 82873    839634.0       Murrieta  California   92563.0      1031.0
# 287835   744771.0  Moreno Valley  California   92553.0      1295.0
#
#        prev_sold_date year_sold month_sold   forsale/sold  city_freq
# 966        1979-05-10      1979        May       for_sale      687.0
# 248881     2022-04-05      2022      April           sold     1139.0
# 159937     2022-01-13      2022    January           sold     1289.0
# 82873      2019-10-15      2019    October       for_sale      858.0
# 287835     2022-04-30      2022      April  for_sale,sold      886.0

# %%
sns.histplot(x = 'price', data = sample_california)
plt.show()

# %% [raw]
# Yearly Patterns

# %%
sample_california.year_sold.value_counts().reset_index().head(5)
# Out:
#   year_sold  count
# 0      2022  12282
# 1      2021   5412
# 2      2019    436
# 3      2017    421
# 4      2018    414

# %%
sample_california.city.unique()
# Out:
# array(['Los Angeles', 'Long Beach', 'Roseville', 'San Diego',
#        'Bakersfield', 'Sacramento', 'Fresno', 'Fontana', 'San Bernardino',
#        'Oakland', 'Victorville', 'Elk Grove', 'Modesto', 'Stockton',
#        'Riverside', 'Moreno Valley', 'Corona', 'Murrieta', 'Menifee',
#        'Temecula'], dtype=object)

# %% [raw]
# insight: The number of houses sold increased every year but the number of houses sold in 2023 decreased.

# %%
sample_california[sample_california.year_sold.astype(int) >= 2010].groupby('year_sold')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#   year_sold          price
# 0      2020  560224.094340
# 1      2015  557025.938776
# 2      2016  548429.254658
# 3      2019  548072.534404
# 4      2018  546893.057971

# %% [raw]
# Monthly_patterns

# %%
month = sample_california.month_sold.value_counts().reset_index(name = 'count')

# %%
sns.barplot( y = 'month_sold', x = 'count', data = month)
plt.show()

# %% [raw]
# Insights: Houses are mostly sold in March, April and December this shows that houses are quite much sold during holiday seasons like Christmas, and Easter.

# %% [raw]
# House Features Analysis

# %%
pd.concat([sample_california.groupby(['bed','bath']).size().reset_index(name = 'count'), sample_california.groupby(['bed','bath'])['price'].mean().reset_index().drop(columns = ['bed','bath']),], axis =1).sort_values('price', ascending = False)
# Out:
#     bed  bath  count          price
# 12  5.0   1.0      1  899000.000000
# 7   3.0   4.0     69  687314.623188
# 11  4.0   4.0    263  675626.965779
# 15  5.0   4.0    203  670853.694581
# 14  5.0   3.0    941  655622.849097
# 10  4.0   3.0   3544  626625.947235
# 3   2.0   4.0      7  621428.571429
# 2   2.0   3.0    210  598247.961905
# 6   3.0   3.0   2528  576507.045491
# 13  5.0   2.0    164  575864.682927
# 9   4.0   2.0   2546  535734.610369
# 5   3.0   2.0   7323  511598.559470
# 8   4.0   1.0     53  497621.113208
# 1   2.0   2.0   2018  486361.268087
# 4   3.0   1.0   1359  471321.339220
# 0   2.0   1.0   2409  462238.314653

# %% [raw]
# insights: Feature wise, the price of house in california also depends on the number of bedrooms and bathrooms.

# %%
sns.histplot(sample_california.house_size)
plt.show()

# %%
sample_california.groupby('house_size')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#    house_size     price
# 0      2949.0  919000.0
# 1      3022.0  900000.0
# 2      3084.0  899000.0
# 3      2970.0  895000.0
# 4      3083.0  880000.0

# %% [raw]
# Houses whose sizes are 2900 square feet and above are the most expensive houses in california.

# %%
sns.histplot(sample_california.acre_lot)
plt.show()

# %%
sample_california.groupby('acre_lot')['price'].mean().sort_values(ascending = False).reset_index().head(7)
# Out:
#    acre_lot          price
# 0      0.32  618899.076923
# 1      0.31  592230.077670
# 2      0.27  589541.636364
# 3      0.28  587912.783133
# 4      0.33  578827.717949
# 5      0.30  578352.321101
# 6      0.26  573952.366516

# %% [raw]
# Insight: Houses whose land area is 0.26 acres and above are the most expensive houses in california

# %%
cities = sample_california.groupby('city')['price'].mean().sort_values(ascending = False).reset_index()

# %%
sns.barplot(y = 'city', x ='price', data = cities, color = 'green')
plt.show()

# %%
sample_california.city.value_counts()
# Out:
# city
# Sacramento        4358
# Stockton          1726
# Los Angeles       1653
# Modesto           1289
# Riverside         1221
# San Diego         1170
# Bakersfield       1139
# Oakland           1122
# San Bernardino    1011
# Roseville          966
# Menifee            946
# Moreno Valley      886
# Elk Grove          862
# Murrieta           858
# Fontana            831
# Victorville        775
# Fresno             731
# Temecula           713
# Corona             694
# Long Beach         687
# Name: count, dtype: int64

# %% [raw]
# insight: As we can see Houses in San Diego are the most expensive houses in california based on the average price of houses taken across each city.

# %% [raw]
# Balancing the dataset to confirm the findings

# %%
sample = sample_california [sample_california.city == 'Long Beach']
for var in list(sample_california.city.unique()):
    if var == 'Long Beach':
        continue
    samp = sample_california[sample_california.city == var].sample(n = 687)
    sample = pd.concat([samp,sample])

# %%
sample.groupby('city')['price'].mean().sort_values(ascending = False).head(20).reset_index()
# Out:
#               city          price
# 0        San Diego  718761.890830
# 1       Long Beach  704329.746725
# 2      Los Angeles  682193.914119
# 3          Oakland  678285.494905
# 4           Corona  676710.989811
# 5         Temecula  654150.633188
# 6        Roseville  626377.598253
# 7        Elk Grove  622813.631732
# 8         Murrieta  586812.671033
# 9          Fontana  586654.024745
# 10       Riverside  557114.449782
# 11         Menifee  504052.542940
# 12   Moreno Valley  496196.727802
# 13      Sacramento  495964.189229
# 14         Modesto  443838.144105
# 15  San Bernardino  441557.000000
# 16        Stockton  430805.331878
# 17     Victorville  398614.071325
# 18          Fresno  369678.981077
# 19     Bakersfield  344468.810771

# %%
sns.heatmap(sample_california[['price','bed','bath','acre_lot','house_size']].corr(numeric_only = True, method ='spearman'), annot = True)
plt.title('An Heatmap Showing the Correlation Between the House Features and Price')
plt.show()

# %% [raw]
# Insight
# - There is a positive strong relationship between bedroom, bathroom and house size. which means the more the rooms in the house the bigger the house.
# - There is positive slightly weak relationship between price and the house features.

# %%
sample_california.shape
# Out:
# (23638, 17)

# %% [markdown]
# ##### __Analyzing Zip Codes__

# %%
dictionary = {}
for city in sample_california.city.unique():
    cal_zipcodes = sample_california.groupby('city')['zip_code'].unique()
    dictionary.update({city: list(cal_zipcodes.loc[city])})

# %%
dictionary['Roseville']
# Out:
# [95661.0, 95678.0, 95747.0]

# %% [raw]
# After taking a sample from the dictionary and performing research to confirm whether the Zip_codes do belong to that particular city. Based on the research, we can conclude that these zip codes do belong to their cities.

# %% [markdown]
# ### Analysis on Houses in Arizona

# %% [raw]
# Arizona is the second state with expensive houses

# %%
arizona = data[data.state == 'Arizona']

# %%
arizona.shape
# Out:
# (37775, 16)

# %%
arizona.head(3)
# Out:
#      Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 159      130755      51755.0  for_sale  365000.0  3.0   2.0      0.19
# 194      130666      33714.0  for_sale  325000.0  3.0   2.0      0.24
# 196      129537     100423.0  for_sale  650000.0  4.0   2.0      0.23
#
#         street    city    state  zip_code  house_size prev_sold_date  \
# 159  1721857.0  Tucson  Arizona   85710.0      1470.0     1970-10-01
# 194   863585.0  Tucson  Arizona   85730.0      2092.0     1971-07-15
# 196  1261102.0  Tucson  Arizona   85701.0      2075.0     1971-08-01
#
#     year_sold month_sold forsale/sold
# 159      1970    October     for_sale
# 194      1971       July     for_sale
# 196      1971     August     for_sale

# %%
ari_city_dict = arizona.city.value_counts().head(20).to_dict()

# %%
arizona['city_freq'] = arizona['city'].map(ari_city_dict)

# %%
sample_arizona = arizona.dropna()

# %%
sns.boxplot(sample_arizona.price, color ='brown')
plt.show()

# %% [raw]
# Monthly_Patterns

# %%
sns.countplot(sample_arizona[sample_arizona['year_sold'].astype(int)>=2010].year_sold, color = 'brown')
plt.show()

# %% [raw]
# insight: This is an upward trend, and the number of houses sold grew each year since 2010

# %%
sample_arizona.groupby(['bed','bath']).size().sort_values(ascending = False).reset_index().head(5)
# Out:
#    bed  bath      0
# 0  3.0   2.0  10859
# 1  2.0   2.0   5219
# 2  4.0   2.0   3896
# 3  4.0   3.0   3123
# 4  3.0   3.0   2642

# %% [raw]
# insights: Houses in Arizona mostly have 3 bedrooms and 2 bathrooms.

# %%
pd.concat([sample_arizona.groupby(['bed','bath']).size().reset_index(), sample_arizona.groupby(['bed','bath'])['price'].mean().reset_index().drop(columns = ['bed','bath'])], axis =1).sort_values('price', ascending = False).head(5)
# Out:
#     bed  bath     0          price
# 11  4.0   4.0   229  601928.296943
# 7   3.0   4.0    83  594504.518072
# 15  5.0   4.0   111  567221.765766
# 14  5.0   3.0   733  529873.540246
# 10  4.0   3.0  3123  524093.359590

# %% [raw]
# Insight: Houses with four bedrooms and four bathrooms are the most expensive houses in arizona

# %%
sample_arizona.shape
# Out:
# (29157, 17)

# %%
sns.countplot(sample_arizona.month_sold, color = 'lightgreen')
plt.grid(True)
plt.show()

# %% [raw]
# insight: Houses are mostly sold in March, April, February and December in Arizona

# %%
arizona_monthly_sales = sample_arizona.groupby('month_sold')['price'].mean().reset_index()

# %%
sns.set_style('darkgrid')
sns.barplot(x = 'price', y ='month_sold', data = arizona_monthly_sales, color = 'brown')
plt.title('Average House Price For Each Month')
plt.show()

# %%
sample_arizona.groupby('month_sold')['price'].mean().sort_values(ascending = False).reset_index()
# Out:
#    month_sold          price
# 0      August  459556.680973
# 1        July  456201.613027
# 2        June  454581.372951
# 3   September  451808.199181
# 4         May  449438.177100
# 5     October  440612.072750
# 6       April  436262.857293
# 7       March  422735.878129
# 8    February  409259.397150
# 9    December  396217.379419
# 10    January  394171.819253
# 11   November  392499.543333

# %%
sample_arizona.groupby('house_size')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#    house_size     price
# 0      2749.0  920000.0
# 1      3032.0  898500.0
# 2      2841.0  895000.0
# 3      2814.0  875000.0
# 4      3128.0  875000.0

# %% [raw]
# insight: Houses whose sizes are 2700 square feet and above are expensive in Arizona

# %%
sample_arizona.year_sold.value_counts().head(10).reset_index().sort_values('count', ascending = False)
# Out:
#   year_sold  count
# 0      2022  16942
# 1      2021   4645
# 2      2020    830
# 3      2019    768
# 4      2018    580
# 5      2017    527
# 6      2016    464
# 7      2015    382
# 8      2014    287
# 9      2005    280

# %%
ari_cities = sample_arizona.groupby('city')['price'].mean().sort_values(ascending = False).reset_index()

# %%
sns.barplot(x ='price',  y = 'city', data = ari_cities, color ='green')
plt.show()

# %% [raw]
# Insight: Houses in Scottsdale, Gilbert, Chandler, Lake Havasu city and Goodyear are the most expensive houses in Arizona.

# %%
sample_arizona.groupby('acre_lot')['price'].mean().sort_values(ascending = False).reset_index().head(7)
# Out:
#    acre_lot          price
# 0      0.33  531211.604651
# 1      0.31  527764.386792
# 2      0.27  515982.780822
# 3      0.24  513016.033663
# 4      0.30  509151.376812
# 5      0.25  507163.352436
# 6      0.26  506867.233038

# %% [raw]
# Insight: Houses whose land area is 0.24 and above are most expensive houses in Arizona.

# %%
sns.heatmap(sample_arizona[['price','bed','bath','acre_lot','house_size']].corr(numeric_only = True, method ='spearman'), annot = True)
plt.title('An Heatmap Showing the Correlation Between the House Features and Price')
plt.show()

# %% [raw]
# Insights
# - The larger the house size in arizona the higher the price.
# - There is positive relationship between the house rooms, land size and house prices.

# %%
ari_dictionary = {}
for city in sample_arizona.city.unique():
    ari_zipcodes = sample_arizona.groupby('city')['zip_code'].unique()
    ari_dictionary.update({city: list(ari_zipcodes.loc[city])})

# %%
ari_dictionary['Scottsdale']
# Out:
# [85251.0,
#  85257.0,
#  85254.0,
#  85258.0,
#  85259.0,
#  85260.0,
#  85250.0,
#  85255.0,
#  85266.0,
#  85262.0,
#  85054.0]

# %% [raw]
# After conducting research we conclude that these zip codes belong to their cities.

# %% [markdown]
# ### Analysis on Houses in Florida

# %%
florida = data[data.state == 'Florida']

# %%
florida.nunique()
# Out:
# Unnamed: 0        72691
# brokered_by        8940
# status                2
# price              5843
# bed                   4
# bath                  4
# acre_lot             32
# street            67181
# city                526
# state                 1
# zip_code            871
# house_size         2529
# prev_sold_date     7380
# year_sold            60
# month_sold           12
# forsale/sold          4
# dtype: int64

# %%
sns.boxplot(florida.house_size)
plt.show()

# %%
flo_city_dict = florida.city.value_counts().head(20).to_dict()

# %%
florida['city_freq'] = florida['city'].map(flo_city_dict)

# %%
sample_florida = florida.dropna()

# %%
sample_florida.shape
# Out:
# (30312, 17)

# %%
sample_florida.city.unique()
# Out:
# array(['Melbourne', 'Orlando', 'Jacksonville', 'Palm Bay', 'Fort Myers',
#        'Port Saint Lucie', 'Cape Coral', 'Lehigh Acres', 'Kissimmee',
#        'Springhill', 'Saint Petersburg', 'Miami', 'North Port', 'Tampa',
#        'Port Charlotte', 'Ocala', 'Lakeland', 'Davenport', 'Pensacola',
#        'Riverview'], dtype=object)

# %%
florida_cities = sample_florida.groupby('city')['price'].mean().sort_values(ascending = False).reset_index()

# %%
sns.barplot(x = 'price', y = 'city',data = florida_cities)
plt.title('Average House Prices In Each City')
plt.show()

# %% [raw]
# Insights
# - Houses in Miami are the most expensive houses in Florida, Cape Coral, Fort Myers and Saint Petersburg.

# %%
sample_florida.groupby(['bed','bath']).size().sort_values(ascending = False).reset_index().head(5)
# Out:
#    bed  bath      0
# 0  3.0   2.0  12509
# 1  4.0   2.0   3760
# 2  2.0   2.0   3396
# 3  4.0   3.0   3133
# 4  3.0   3.0   2732

# %% [raw]
# Insight: Most houses in Florida has 3 bedrooms and 2 bathrooms

# %%
sns.histplot(x ='price', color = 'green', data = sample_florida)
plt.show()

# %% [raw]
# insight:Most Houses are priced within the range of 200k and 400k

# %%
pd.concat([sample_florida.groupby(['bed','bath']).size().reset_index(name = 'count'), sample_florida.groupby(['bed','bath'])['price'].mean().reset_index().drop(columns = ['bed','bath']),], axis =1).sort_values('price', ascending = False).head(5)
# Out:
#     bed  bath  count          price
# 11  4.0   4.0    476  531958.231092
# 7   3.0   4.0    227  531484.356828
# 15  5.0   4.0    230  516431.956522
# 14  5.0   3.0    483  480052.115942
# 10  4.0   3.0   3133  472253.657517

# %% [raw]
# Insights: The most expensive houses are houses with four bedrooms and four bathrooms

# %%
sample_florida.groupby('house_size')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#    house_size     price
# 0      2676.0  900000.0
# 1      2353.0  899999.0
# 2      3116.0  899000.0
# 3      3035.0  895000.0
# 4      2817.0  895000.0

# %% [raw]
# Insights: Florida Houses whose sizes are 2300 square feet and above are the most expensive.

# %%
sns.countplot(sample_florida.month_sold)
plt.show()

# %% [raw]
# Insights: Houses in Florida are mostly sold in March.

# %% [raw]
# Checking Correlation

# %%
sns.heatmap(sample_florida[['price','bed','bath','acre_lot','house_size']].corr(numeric_only = True, method ='spearman'), annot = True)
plt.title('An Heatmap Showing the Correlation Between the House Features and Price')
plt.show()

# %% [raw]
# Insight: There is a strong positive relationship between house sizes and their prices

# %%
sample_florida.shape
# Out:
# (30312, 17)

# %% [markdown]
# ### Analysis on Houses in Texas

# %%
texas = data[data.state == 'Texas']

# %%
texas.shape
# Out:
# (72605, 16)

# %% [raw]
# selecting 20 cities in Texas

# %%
tex_cities_dict = texas.city.value_counts().head(20).to_dict()

# %%
texas['city_freq'] = texas.city.map(tex_cities_dict)

# %%
sample_texas = texas.dropna()

# %%
sample_texas.shape
# Out:
# (40105, 17)

# %%
# %matplotlib inline

# %%
sns.boxplot(sample_texas.price)
plt.show()

# %% [raw]
# These are outliers but we can comeback to them if they do affect our model's performance

# %%
sample_texas.groupby(['bed','bath']).size().sort_values(ascending = False).reset_index().head(5)
# Out:
#    bed  bath      0
# 0  3.0   2.0  14238
# 1  4.0   3.0   6966
# 2  3.0   3.0   5547
# 3  4.0   2.0   4585
# 4  3.0   4.0   1532

# %% [raw]
# Insight: Most of the Houses in Florida has 3 bedrooms and 2 bathrooms.

# %%
pd.concat([sample_texas.groupby(['bed','bath']).size().reset_index(name ='count'), sample_texas.groupby(['bed','bath'])['price'].mean().reset_index().drop(columns = ['bed','bath'])],axis = 1).sort_values('price', ascending = False).head(4)
# Out:
#     bed  bath  count          price
# 7   3.0   4.0   1532  493175.917755
# 3   2.0   4.0     31  469108.516129
# 11  4.0   4.0   1282  462718.731669
# 15  5.0   4.0    265  413192.966038

# %% [raw]
# Insight: Houses with three bedrooms and four bathrooms are the most exepensive house in florida.

# %%
monthly_sales = sample_texas.groupby('month_sold')['price'].mean().sort_values(ascending = False).round().reset_index()

# %%
sns.barplot(x = 'price', y ='month_sold', data = monthly_sales, color = 'green')
plt.show()

# %% [raw]
# Insight: Houses sold in June are the most expensive houses based on the average price of houses taken across each month.

# %%
sns.histplot(sample_texas.price, bins = 50)
plt.show()

# %% [raw]
# Insights: The price of most houses in florida are within the range of 250k dollars and 300k dollars.

# %% [raw]
# checking price average across each city

# %%
city_avg = sample_texas.groupby('city')['price'].mean().round().sort_values(ascending = False).reset_index()

# %%
sns.barplot(x = 'price', y ='city', data = city_avg, color = 'orange')
plt.title('Average House Price across each City')
plt.show()

# %% [raw]
# Insight: The most expensive houses in texas are in Austin, Plano, Dallas and Cypress.

# %%
sample_texas.groupby('acre_lot')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#    acre_lot          price
# 0      0.04  400041.000806
# 1      0.29  387840.454874
# 2      0.06  382904.404378
# 3      0.05  381080.360190
# 4      0.27  374656.128280

# %%
sns.heatmap(sample_texas[['price','bed','bath','acre_lot','house_size']].corr(numeric_only = True, method ='spearman'), annot = True)
plt.title('An Heatmap Showing the Correlation Between the House Features and House Price')
plt.show()

# %% [raw]
# Insights:
# - There is a very weak relationship between price and land size.
# - The Larger the size of the houses in Texas, the higher their price.
# - Bathrooms influence house price in Texas too.

# %% [markdown]
# ### Analysis on Houses in Pennsylvania

# %%
pennsylvania = data[data.state == 'Pennsylvania']

# %%
pennsylvania.shape
# Out:
# (25913, 16)

# %%
pennsylvania.describe()
# Out:
#           Unnamed: 0    brokered_by          price           bed  \
# count   25913.000000   25913.000000   25913.000000  25913.000000
# mean   110923.572647   45894.865782  241348.379925      3.143789
# std     95352.677269   28383.855781  135342.825036      0.710543
# min         2.000000       5.000000   11500.000000      2.000000
# 25%      9439.000000   20269.000000  149000.000000      3.000000
# 50%    190082.000000   48532.000000  219000.000000      3.000000
# 75%    200489.000000   74476.000000  309000.000000      3.000000
# max    262669.000000  110141.000000  915000.000000      5.000000
#
#                bath      acre_lot        street      zip_code    house_size
# count  25913.000000  25913.000000  2.591300e+04  25913.000000  25913.000000
# mean       2.013275      0.123151  9.139570e+05  17909.665072   1578.760583
# std        0.812297      0.090460  5.140983e+05   1461.800744    497.732096
# min        1.000000      0.020000  6.085000e+03  15001.000000    400.000000
# 25%        1.000000      0.040000  4.811690e+05  17046.000000   1200.000000
# 50%        2.000000      0.100000  9.290680e+05  18466.000000   1486.000000
# 75%        3.000000      0.190000  1.360007e+06  19128.000000   1880.000000
# max        4.000000      0.330000  1.982920e+06  19611.000000   3131.000000

# %%
sns.boxplot(pennsylvania.price)
plt.show()

# %% [raw]
# Selecting Top 20 cities

# %%
pen_city_dict = pennsylvania.city.value_counts().head(20).to_dict()

# %%
pennsylvania['city_freq'] = pennsylvania['city'].map(pen_city_dict)

# %%
sample_pennsylvania = pennsylvania.dropna()

# %%
sample_pennsylvania.shape
# Out:
# (12597, 17)

# %%
sample_pennsylvania.groupby(['bed','bath']).size().sort_values(ascending = False).reset_index().head(5)
# Out:
#    bed  bath     0
# 0  3.0   2.0  3427
# 1  3.0   1.0  2603
# 2  3.0   3.0  1444
# 3  4.0   2.0  1185
# 4  2.0   1.0   888

# %% [raw]
# Insight: It has become a pattern most of the houses in the five states has 3 bedrooms and 2 bathrooms.

# %%
pd.concat([sample_pennsylvania.groupby(['bed','bath']).size().reset_index(name ='count'), sample_pennsylvania.groupby(['bed','bath'])['price'].mean().reset_index().drop(columns = ['bed','bath'])],axis = 1).sort_values('price', ascending = False).head(4)
# Out:
#     bed  bath  count          price
# 7   3.0   4.0    175  470584.582857
# 11  4.0   4.0    178  450860.022472
# 15  5.0   4.0     61  450635.901639
# 3   2.0   4.0      9  394700.000000

# %% [raw]
# Insight: Houses with 3 bedrooms and 4 bathrooms are the most expensive houses in pennslyvania.

# %%
monthly_sale = sample_pennsylvania.groupby('month_sold')['price'].mean().sort_values(ascending = False).round().reset_index()

# %%
sns.barplot(x = 'price', y = 'month_sold', data = monthly_sale)
plt.show()

# %% [raw]
# Most expensive houses in pennsylvania are always sold in May, July and August.

# %%
yearly_pattern = sample_pennsylvania.year_sold.value_counts().head(20).reset_index().sort_values('year_sold')

# %%
plt.figure (figsize = (10,4))
sns.lineplot(y= 'count', x = 'year_sold', data = yearly_pattern, marker = 'o', color = 'brown')
plt.show()

# %% [raw]
# Insight: Lot's houses in Pennsylvania were sold in 2022

# %%
sns.histplot(sample_pennsylvania.price)
plt.show()

# %% [raw]
# Insights: Houses around 800k dollars and above are not quite much  but most houses are priced around 200k dollars.

# %%
city_average = sample_pennsylvania.groupby('city')['price'].mean().sort_values(ascending = False).reset_index()

# %%
sns.barplot(x ='price', y ='city', data = city_average, color ='green')
plt.show()

# %% [raw]
# Insight: Houses in West Chester are the most expensive.

# %%
sample_pennsylvania.groupby('house_size')['price'].mean().sort_values(ascending = False).reset_index().head(5)
# Out:
#    house_size     price
# 0      2791.0  900000.0
# 1      2497.0  875000.0
# 2      3030.0  865000.0
# 3      2873.0  829900.0
# 4      2918.0  825000.0

# %% [raw]
# Insight: houses within the range of 2400 and 3030 square feet are the most expensive houses.

# %% [raw]
# checking relationship

# %%
sns.heatmap(sample_pennsylvania[['price','bed','bath','acre_lot','house_size']].corr(numeric_only = True, method ='spearman'), annot = True)
plt.title('An Heatmap Showing the Correlation Between the House Features and House Price')
plt.show()

# %% [raw]
# Insight:
# - Bathrooms really influences the price of houses in california
# - The number of bedrooms doesn't really influence prices.

# %% [markdown]
# ## __Combining the cities we would be working with.__

# %% [raw]
# Checking the total number of rows we would be working with.

# %%
states_datasets = [sample_california, sample_arizona, sample_florida, sample_texas, sample_pennsylvania]

# %%
cali_shape = sample_california.shape[0]
for state in states_datasets:
    if state is sample_california:
        continue
    total_length = state.shape[0]
    cali_shape += total_length

# %%
print(f'The total number of rows we would be working with is {cali_shape}')
# Out:
# The total number of rows we would be working with is 135809

# %% [raw]
# merging the dataframes

# %%
merged_data = pd.concat(states_datasets)

# %%
merged_data.nunique()
# Out:
# Unnamed: 0        135809
# brokered_by        16333
# status                 2
# price               8125
# bed                    4
# bath                   4
# acre_lot              32
# street            124996
# city                 100
# state                  5
# zip_code            1206
# house_size          2563
# prev_sold_date      8815
# year_sold             62
# month_sold            12
# forsale/sold           4
# city_freq             97
# dtype: int64

# %%
merged_data.shape
# Out:
# (135809, 17)

# %% [raw]
# Shuffling the dataframe

# %%
merged_data.head(5)
# Out:
#     Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 14      135080      82036.0  for_sale  870000.0  4.0   2.0      0.16
# 15      138547      38169.0  for_sale  524000.0  3.0   1.0      0.12
# 17      137209      17170.0  for_sale  675000.0  3.0   2.0      0.13
# 21      134432      53691.0  for_sale  450000.0  3.0   1.0      0.12
# 27      134418      16040.0  for_sale  660000.0  4.0   3.0      0.12
#
#        street         city       state  zip_code  house_size prev_sold_date  \
# 14  1405290.0  Los Angeles  California   90016.0      1809.0     1964-06-04
# 15   150537.0  Los Angeles  California   90059.0      1082.0     1964-06-09
# 17   853644.0  Los Angeles  California   90033.0      1388.0     1964-07-23
# 21  1170956.0  Los Angeles  California   90003.0      1464.0     1964-09-03
# 27  1771198.0  Los Angeles  California   90001.0      1760.0     1964-12-29
#
#    year_sold month_sold   forsale/sold  city_freq
# 14      1964       June  for_sale,sold     1653.0
# 15      1964       June  for_sale,sold     1653.0
# 17      1964       July       for_sale     1653.0
# 21      1964  September       for_sale     1653.0
# 27      1964   December       for_sale     1653.0

# %%
merged_data = merged_data.sample(n = merged_data.shape[0], random_state = 46).reset_index(drop = True)

# %%
merged_data.head(5)
# Out:
#    Unnamed: 0  brokered_by    status     price  bed  bath  acre_lot  \
# 0        2612      83377.0  for_sale  198000.0  4.0   2.0      0.04
# 1      364154      28969.0      sold  849000.0  3.0   3.0      0.30
# 2      409621       7960.0      sold  475000.0  2.0   1.0      0.15
# 3      330000      53016.0      sold  299000.0  3.0   3.0      0.16
# 4      370552      67618.0      sold  649880.0  2.0   1.0      0.09
#
#       street          city         state  zip_code  house_size prev_sold_date  \
# 0  1586992.0  Philadelphia  Pennsylvania   19142.0      1152.0     1996-02-05
# 1   414148.0   Los Angeles    California   90035.0      1574.0     2022-04-08
# 2  1222881.0     Riverside    California   92506.0       864.0     2022-03-29
# 3  1479006.0       El Paso         Texas   79912.0      2153.0     2021-11-15
# 4   539297.0   Los Angeles    California   90047.0      1046.0     2021-12-08
#
#   year_sold month_sold forsale/sold  city_freq
# 0      1996   February     for_sale     5069.0
# 1      2022      April         sold     1653.0
# 2      2022      March         sold     1221.0
# 3      2021   November         sold     2782.0
# 4      2021   December         sold     1653.0

# %% [markdown]
# ### __Data Preprocessing__

# %% [raw]
# we would dropping some columns and perform data transformation

# %%
merged_data.drop(columns = ['year_sold','month_sold','forsale/sold','city_freq', 'status','street','prev_sold_date','brokered_by'], inplace = True)

# %%
merged_data.sample(3)
# Out:
#        Unnamed: 0     price  bed  bath  acre_lot            city  \
# 21810       59894  238900.0  3.0   2.0      0.20  Port Charlotte
# 90230      190439  325000.0  4.0   3.0      0.11     Drexel Hill
# 7299       294989  125000.0  3.0   1.0      0.21         Houston
#
#               state  zip_code  house_size
# 21810       Florida   33952.0      1053.0
# 90230  Pennsylvania   19026.0      1934.0
# 7299          Texas   77091.0      1272.0

# %%
'''converting the zipcodes, number of bedrooms and bathrooms  to integer we might need them.'''
merged_data['zip_code'] = merged_data['zip_code'].astype(int)

# %%
merged_data = merged_data.astype({'bed':int, 'bath': int})

# %%
merged_data.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# bed           0
# bath          0
# acre_lot      0
# city          0
# state         0
# zip_code      0
# house_size    0
# dtype: int64

# %% [raw]
# checking for duplicated entries

# %%
merged_data.duplicated().sum() # we would have to drop these values so that they won't affect our model performance
# Out:
# 0

# %%
merged_data.drop_duplicates(inplace =True)

# %%
merged_data.shape
# Out:
# (135809, 9)

# %%
merged_data.sample(3)
# Out:
#        Unnamed: 0     price  bed  bath  acre_lot          city         state  \
# 21079      118791  675000.0    3     2      0.17      Chandler       Arizona
# 77544      298184  270000.0    3     3      0.11       Houston         Texas
# 70937      208165  234900.0    3     3      0.06  Philadelphia  Pennsylvania
#
#        zip_code  house_size
# 21079     85249      2096.0
# 77544     77086      1760.0
# 70937     19111      1575.0

# %% [markdown]
# ### Feature Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
city_encoder = LabelEncoder()

# %%
state_encoder = LabelEncoder()

# %%
merged_data['city'] = city_encoder.fit_transform(merged_data['city'])

# %%
merged_data['state'] = state_encoder.fit_transform(merged_data['state'])

# %%
merged_data
# Out:
#         Unnamed: 0     price  bed  bath  acre_lot  city  state  zip_code  \
# 0             2612  198000.0    4     2      0.04    63      3     19142
# 1           364154  849000.0    3     3      0.30    45      1     90035
# 2           409621  475000.0    2     1      0.15    72      1     92506
# 3           330000  299000.0    3     3      0.16    18      4     79912
# 4           370552  649880.0    2     1      0.09    45      1     90047
# ...            ...       ...  ...   ...       ...   ...    ...       ...
# 135804      223742  617000.0    4     3      0.26    58      2     32820
# 135805       77395  427000.0    5     3      0.13    23      4     76262
# 135806       33739  340000.0    3     3      0.04    58      2     32825
# 135807      130656  395000.0    4     2      0.19    93      0     85757
# 135808      251441  435000.0    2     2      0.15    55      2     34289
#
#         house_size
# 0           1152.0
# 1           1574.0
# 2            864.0
# 3           2153.0
# 4           1046.0
# ...            ...
# 135804      2614.0
# 135805      2402.0
# 135806      1373.0
# 135807      2002.0
# 135808      1467.0
#
# [135809 rows x 9 columns]

# %% [markdown]
# ### Data Segmentation

# %%
X = merged_data.drop('price', axis = 1)

# %%
Y = merged_data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(X_test)

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.39943613036033876

# %%
linear_model.intercept_
# Out:
# 141659.48610136902

# %%
linear_model.coef_
# Out:
# array([-4.84672659e-02, -1.18831437e+04,  2.75487537e+04,  8.78367251e+04,
#        -1.06627331e+02, -4.29253963e+04,  1.27125833e+00,  1.31395450e+02])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr_model = RandomForestRegressor()

# %%
rfr_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
r2_score(Y_test, rfr_model.predict(X_test))
# Out:
# 0.8345661166662937
